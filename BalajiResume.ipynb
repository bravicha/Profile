# %%
# Text Variables
Header = '>>>This resume was generated entirely in Python. For full sourcecode, view my github QR code.'
Name = 'BALAJI RAVICHANDRAN'
Title = 'Data Analytics & Visualization Project Lead'
Company = 'Depuy Synthes ( Johnson & Johnson), Ringaskiddy, Cork, Ireland'
Employer = 'Designation: Associate Manager                                    \nEmployer: HCL Technologies'
Contact = 'Mobile:\n  +353 8943208637 \nEmail:\n  balajir@live.in'
Address = 'Linkedin.com/in/balajiravichandran        Github.com/bravicha'
ProjectsHeader1 = 'Depuy Synthes (Johnson & Johnson) '
ProjectTitle1 = 'Recent Project: Operations Technology Development team – Data visualization and analytics'
ProjectDesc1 = ' - Created and  Supported development of analytics to Operations, Management and Quality teams.\n - Interacted with technical and management stake holders to develop analytics solutions.\n - Automated repetitive task.\n - Supported decision making for in-house development or outsourcing.\n - Reviewed and prioritized tasks for self and team members.\n - Provided technical consultancy as SME and trainings for team members.'
ProjAch = 'Achievements'
ProjAchlist = ' - Improvised 3% lead time for product production.\n - Reduced Scrap quantities 6% by integrated analysis of scrap reasons.\n - Enabled maintenance of downtime for assets by planned and unplanned.\n - Enabled Capacity analysis for product cycle time vs demand quantities to produce.\n - OSI Pi utilization to support decision making for additional site asset.'
ProjectTitle2 = 'Previous Project: Innovation Management team – Business Intelligence and analytics'
ProjectDesc2a = ' - Trained successor onsite team leader. Supported after deployment for ongoing developments.'
ProjectDesc2b = ' - Analyzed PMO cork projects (capital, savings, business baseline and forecast vs actual)\n - Oracle DB data analysis on ERP Primevera based PMO tool - Instantis.\n - Introduced Qlik sense to Depuy Synthes, Cork.\n - On successful deployment of BI, enabled 70K USD Value addition\n - Implemented Qlik sense across 5 sites. \n - Qlik sense became approved tool across all JNJ PMO.'
ProjectDesc2c = ' - Worked as PMO analyst to automate manual excel reports and analysis.\n - Business travelled 2 weeks to cork to evaluate BI deployment opportunities.\n - Evaluated BI tools based on vendor demos and reviews.'
ProjectTitle3 = 'ERS-WPC (Workforce Planning Cell) – HCL'
ProjectDesc3 = ' - Mapped 5000 job openings demand with skills and availability within internal 80,000 employees.'
ProjectTitle4 = 'KLA-Tencor - HCL '
ProjectDesc4 = ' - As PMO for SDU head for 400 employees created reports, presentations, analysis and automation.'
ProjectTitle5 = 'Tenet Technetronics'
ProjectDesc5 = ' - Created 5 projects on Arduino Hardware with processing front end. Conducted workshops across India.'
ProjectTitle6 = 'AC Nielsen - TCS'
ProjectDesc6 = ' - Analyzed market research reports data to recommend frontline products for 6 US AC Nielsen customers.'
ProjectTitle7 = 'Tenet Technetronics'
ProjectDesc7 = ' - Performed front end VB6 coding and hardware soldering for 20 university student projects.'
Duration1 = 'Cork :     Sep 2018 – May 2020'
Duration2 = 'Chennai:   Mar 2018 – Sep 2018'
Duration3 = 'Cork:      Apr 2016 – Mar 2018'
Duration4 = 'Chennai:   Jun 2014 – Apr 2016'
Duration5 = 'Chennai:   Jan 2014 – Jun 2014'
Duration6 = 'Chennai:   Aug 2012 – Jan 2014'
Duration7 = 'Bangalore: Jan 2010 – Jun 2010'
Duration8 = 'Chennai:   Sep 2008 – Jan 2010'
Duration9 = 'Bangalore: Jul 2007 – Aug 2008'
Duration10 = 'Chennai:   Jun 2010 – Apr 2012'
Duration11 = 'Chennai:   Jun 2003 – Apr 2007'
EduHeader = 'Education'
Edu1 = 'MBA in Finance & HR – SASTRA University'
Edu2 = 'BE in Electronics & Communication – Anna University'
Edutrtitle = 'Training'
Edutraining = ' - Qlik Data visualization best practices\n - Qlik sense advanced Data modelling'
EduCerttitle = 'Certification'
EduCertification = 'Tableau Certified\n Desktop Associate'
Reftitle = 'References:'
References = 'Available upon request'
SkillsHeader = 'Skills'
SkillsDesc = '\n- Tableau\n- Qlik View\n- Qlik Sense\n- Python\Django \n- Team Managament\n- Alteryx\n- Git Version Control\n- SQL\n- HTML\CSS\JS\n- Data Cleaning\n- Data Manipulation\n- Data Visualization\n- Excel Macro'
Showcode = 'View Github'

# Setting style for bar graphs
from docx import Document
from docx.shared import Inches
from pandas.compat import StringIO
import matplotlib.pyplot as plt
# %matplotlib inline

# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'

fig, ax = plt.subplots(figsize=(15, 20))

# Decorative Lines
plt.axvline(x=.02, ymin=0, ymax=.732, color='#004570', alpha=0.99, linewidth=250)
ax.axvline(x=.5, ymin=0, ymax=1, color='#ff0000', alpha=0.0, linewidth=50)
plt.axhline(y=.99, xmin=.297, xmax=1, color='#f0f0f0', linewidth=200)
plt.axhline(y=.874, xmin=.720, xmax=1, color='#f0f0f0', linewidth=17)
plt.axhline(y=.622, xmin=.720, xmax=1, color='#f0f0f0', linewidth=17)
plt.axhline(y=.59, xmin=.720, xmax=1, color='#f0f0f0', linewidth=17) 
plt.axhline(y=.486, xmin=.720, xmax=1, color='#f0f0f0', linewidth=17)
plt.axhline(y=.418, xmin=.720, xmax=1, color='#f0f0f0', linewidth=17)
plt.axhline(y=.3785, xmin=.720, xmax=1, color='#f0f0f0', linewidth=17)
plt.axhline(y=.3385, xmin=.720, xmax=1, color='#f0f0f0', linewidth=17)
plt.axhline(y=.299, xmin=.720, xmax=1, color='#f0f0f0', linewidth=17) 
plt.axhline(y=.26, xmin=.720, xmax=1, color='#f0f0f0', linewidth=17)
plt.axhline(y=.2, xmin=.720, xmax=1, color='#f0f0f0', linewidth=17) 
plt.axhline(y=.18, xmin=.720, xmax=1, color='#f0f0f0', linewidth=17)
ax.axvline(x=.171, ymin=0.895, ymax=1, color='#ff0000', alpha=0.8, linewidth=5)

# set background color
ax.set_facecolor('white')

# remove axes
plt.axis('off')

# add text
plt.annotate(Name, (.2,.97), weight='bold', fontsize=20)
plt.annotate(Title, (.2,.94), weight='regular', fontsize=16)
plt.annotate(Employer, (.2,.910), weight='regular', fontsize=15)
plt.annotate(Contact, (.75,.93), weight='regular', fontsize=16, color='#000000')
plt.annotate(Address, (.5,.910), weight='regular', fontsize=14, color='#000000')
plt.annotate(Header, (.18,.011), weight='regular', fontsize=12, alpha=.6)
plt.annotate(ProjectsHeader1, (.18,.87), weight='bold', fontsize=16, color='#000000')
plt.annotate(ProjectTitle1, (.18,.852), weight='bold', fontsize=14, color='#000000')
plt.annotate(ProjectDesc1, (.18,.758), weight='regular', fontsize=16, color='#000000')
plt.annotate(ProjAch, (.18,.735), weight='bold', fontsize=14, color='#000000')
plt.annotate(ProjAchlist, (.18,.655), weight='regular', fontsize=16, color='#000000')
plt.annotate(ProjectTitle2, (.18,.634), weight='bold', fontsize=14, color='#000000')
plt.annotate(ProjectDesc2a, (.18,.6028), weight='regular', fontsize=16, color='#000000')
plt.annotate(ProjectDesc2b, (.18,.5002), weight='regular', fontsize=16, color='#000000')
plt.annotate(ProjectDesc2c, (.18,.437), weight='regular', fontsize=16, color='#000000')
plt.annotate(ProjectTitle3, (.18,.415), weight='bold', fontsize=14, color='#000000')
plt.annotate(ProjectDesc3, (.18,.395), weight='regular', fontsize=16, color='#000000')
plt.annotate(ProjectTitle4, (.18,.375), weight='bold', fontsize=14, color='#000000')
plt.annotate(ProjectDesc4, (.18,.355), weight='regular', fontsize=16, color='#000000')
plt.annotate(ProjectTitle5, (.18,.335), weight='bold', fontsize=14, color='#000000')
plt.annotate(ProjectDesc5, (.18,.315), weight='regular', fontsize=16, color='#000000')
plt.annotate(ProjectTitle6, (.18,.295), weight='bold', fontsize=14, color='#000000')
plt.annotate(ProjectDesc6, (.18,.275), weight='regular', fontsize=16, color='#000000')
plt.annotate(ProjectTitle7, (.18,.255), weight='bold', fontsize=14, color='#000000')
plt.annotate(ProjectDesc7, (.18,.235), weight='regular', fontsize=16, color='#000000')
plt.annotate(Duration1, (.762,.87), weight='regular', fontsize=14)
plt.annotate(Duration2, (.762,.618), weight='regular', fontsize=14)
plt.annotate(Duration3, (.762,.586), weight='regular', fontsize=14)
plt.annotate(Duration4, (.762,.482), weight='regular', fontsize=14)
plt.annotate(Duration5, (.762,.414), weight='regular', fontsize=14)
plt.annotate(Duration6, (.762,.3745), weight='regular', fontsize=14)
plt.annotate(Duration7, (.762,.3345), weight='regular', fontsize=14)
plt.annotate(Duration8, (.762,.295), weight='regular', fontsize=14)
plt.annotate(Duration9, (.762,.256), weight='regular', fontsize=14)
plt.annotate(Duration10, (.762,.196), weight='regular', fontsize=14)
plt.annotate(Duration11, (.762,.176), weight='regular', fontsize=14)
plt.annotate(EduHeader, (.18,.215), weight='bold', fontsize=16, color='#000000')
plt.annotate(Edu1, (.18,.195), weight='regular', fontsize=14, color='#000000')
plt.annotate(Edu2, (.18,.177), weight='regular', fontsize=14, color='#000000')
plt.annotate(Edutrtitle, (.18,.157), weight='bold', fontsize=14, color='#000000')
plt.annotate(Edutraining, (.18,.12), weight='regular', fontsize=14, color='#000000')
plt.annotate(EduCerttitle, (.01,.597), weight='bold', fontsize=16, color='#ffffff')
plt.annotate(EduCertification, (.01,.56), weight='regular', fontsize=14, color='#ffffff')
plt.annotate(Reftitle, (.18,.067), weight='bold', fontsize=14, color='#000000')
plt.annotate(References, (.18,.047), weight='regular', fontsize=14, color='#000000')
plt.annotate(SkillsHeader, (.01,.83), weight='bold', fontsize=16, color='#ffffff')
plt.annotate(SkillsDesc, (.01,.64), weight='regular', fontsize=14, color='#ffffff')
plt.annotate(Showcode, (.01,.184), weight='regular', fontsize=14, color='#ffffff')
#plt.annotate(Company, (.2,.025), weight='regular', fontsize=12)

#add qr code
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg

arr_code = mpimg.imread('BalajiResumesource.png')
brr_code = mpimg.imread('balaji.png')
imagebox = OffsetImage(arr_code, zoom=0.8)
pimagebox = OffsetImage(brr_code, zoom=0.99)
ab = AnnotationBbox(imagebox, (0.084, 0.12))
ax.add_artist(ab)
# imagebox = OffsetImage(arr_code, zoom=0.9)
# ak = AnnotationBbox(imagebox, (0.02, 0.92))
# ax.add_artist(ak)
ab = AnnotationBbox(pimagebox, (0.084, 0.926))
ax.add_artist(ab)
plt.savefig('BalajiResume.png', dpi=200, bbox_inches='tight')
memfile = StringIO()
plt.savefig(memfile)
document = Document()
document.add_heading('Report',0)
document.add_picture(memfile, width=Inches(1.25))
document.save('BalajiResume.docx')
